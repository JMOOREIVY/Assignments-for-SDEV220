# %%
# How many seconds are in an hour? 60
How_many_seconds_are_in_an_hour = 60 * 60
print(How_many_seconds_are_in_an_hour)
# Out:
# 3600

# %%
#Assign the result from the previous task to a variable called seconds_per_hour
seconds_per_hour = How_many_seconds_are_in_an_hour
print(seconds_per_hour)
# Out:
# 3600

# %%
#How many seconds are in a day? 86400, Also included step 3.4 and saved it in a variable called seconds_per_day
seconds_per_day = (seconds_per_hour * 24)
print(seconds_per_day)
# Out:
# 86400

# %%
#Divide seconds_per_day by seconds_per_hour using floating-point division (/)
seconds_per_day / seconds_per_hour
# Out:
# 24.0

# %%
#Divide seconds_per_day by seconds_per_hour using integer division (//)
seconds_per_day // seconds_per_hour
#Did this number agree with the floating-point value from the previous question, aside from the final .0? Yes it did
# Out:
# 24
